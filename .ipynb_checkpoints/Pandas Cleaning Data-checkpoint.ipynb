# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
flights_data = pd.read_csv('flights.csv')
flights_data.head(10)
weather_data_pd = pd.read_csv('weather.csv')
weather_data_np = weather_data_pd.to_numpy()

# %%
flights_data.head()
# Out:
#    Unnamed: 0  year  month  day  dep_time  dep_delay  arr_time  arr_delay  \
# 0           1  2013      1    1     517.0        2.0     830.0       11.0
# 1           2  2013      1    1     533.0        4.0     850.0       20.0
# 2           3  2013      1    1     542.0        2.0     923.0       33.0
# 3           4  2013      1    1     544.0       -1.0    1004.0      -18.0
# 4           5  2013      1    1     554.0       -6.0     812.0      -25.0
#
#   carrier tailnum  flight origin dest  air_time  distance  hour  minute
# 0      UA  N14228    1545    EWR  IAH     227.0      1400   5.0    17.0
# 1      UA  N24211    1714    LGA  IAH     227.0      1416   5.0    33.0
# 2      AA  N619AA    1141    JFK  MIA     160.0      1089   5.0    42.0
# 3      B6  N804JB     725    JFK  BQN     183.0      1576   5.0    44.0
# 4      DL  N668DN     461    LGA  ATL     116.0       762   5.0    54.0

# %%
flights_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 336776 entries, 0 to 336775
# Data columns (total 17 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Unnamed: 0  336776 non-null  int64
#  1   year        336776 non-null  int64
#  2   month       336776 non-null  int64
#  3   day         336776 non-null  int64
#  4   dep_time    328521 non-null  float64
#  5   dep_delay   328521 non-null  float64
#  6   arr_time    328063 non-null  float64
#  7   arr_delay   327346 non-null  float64
#  8   carrier     336776 non-null  object
#  9   tailnum     334264 non-null  object
#  10  flight      336776 non-null  int64
#  11  origin      336776 non-null  object
#  12  dest        336776 non-null  object
#  13  air_time    327346 non-null  float64
#  14  distance    336776 non-null  int64
#  15  hour        328521 non-null  float64
#  16  minute      328521 non-null  float64
# dtypes: float64(7), int64(6), object(4)
# memory usage: 43.7+ MB

# %% [markdown]
# ### Question 1 How many flights were there from JFK to SLC? Int

# %% [markdown]
# #Question 4 What proportion of flights to SEA come from the two NYC
# airports (LGA and JFK)?  float

# %%
x = flights_data[(flights_data.dest == "SEA")]
x[(x.origin == "LGA") | (x.origin == "JFK")].count()
# Out:
# Unnamed: 0    2092
# year          2092
# month         2092
# day           2092
# dep_time      2080
# dep_delay     2080
# arr_time      2079
# arr_delay     2075
# carrier       2092
# tailnum       2091
# flight        2092
# origin        2092
# dest          2092
# air_time      2075
# distance      2092
# hour          2080
# minute        2080
# dtype: int64

# %%
# There were 2092 flights from LGA and JFK to SEA

# %%
x
# Out:
#         Unnamed: 0  year  month  day  dep_time  dep_delay  arr_time  \
# 78              79  2013      1    1     724.0       -1.0    1020.0
# 93              94  2013      1    1     743.0       13.0    1059.0
# 165            166  2013      1    1     857.0        6.0    1157.0
# 401            402  2013      1    1    1418.0       -1.0    1726.0
# 404            405  2013      1    1    1421.0       26.0    1735.0
# ...            ...   ...    ...  ...       ...        ...       ...
# 336585      336586  2013      9   30    1829.0       -1.0    2152.0
# 336586      336587  2013      9   30    1829.0       -6.0    2153.0
# 336587      336588  2013      9   30    1830.0       30.0    2138.0
# 336652      336653  2013      9   30    1934.0        4.0    2236.0
# 336685      336686  2013      9   30    2008.0       33.0    2322.0
#
#         arr_delay carrier tailnum  flight origin dest  air_time  distance  \
# 78          -10.0      AS  N594AS      11    EWR  SEA     338.0      2402
# ...
